# %%
#import lib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import operator
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %%
np.random.seed(0)
x = 2 - 3 * np.random.normal(0, 1, 20)
y = x - 2 * (x**2) + np.random.normal(-3, 3, 20)

x = x[:, np.newaxis]
y = y[:, np.newaxis]

degree = 2
polynomial_features = PolynomialFeatures(degree=degree)
x_poly = polynomial_features.fit_transform(x)

model = LinearRegression()
model.fit(x_poly, y)
y_poly_pred = model.predict(x_poly)

plt.scatter(x, y, color='blue')
sorted_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(x, y_poly_pred), key=sorted_axis)
x, y_poly_pred = zip(*sorted_zip)

plt.plot(x, y_poly_pred, color='magneta')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Polynomial Regression')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 17
#      13 model.fit(x_poly, y)
#      14 y_poly_pred = model.predict(x_poly)
#      15
#      16 plt.scatter(x, y, color='blue')
# ---> 17 sorted_axis = operator.itemgetter(0)
#      18 sorted_zip = sorted(zip(x, y_poly_pred), key=sorted_axis)
#      19 x, y_poly_pred = zip(*sorted_zip)
#      20
#
# NameError: name 'operator' is not defined
