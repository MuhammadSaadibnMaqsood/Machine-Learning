# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn import tree
import matplotlib.pyplot as plt

from sklearn.datasets import load_iris

iris = load_iris()
x = iris.data
y = iris.target

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

clf = DecisionTreeClassifier(criterion="entropy", random_state=42)
clf.fit(x_train, y_train)

y_pred = clf.predict(x_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))

tree.plot_tree(clf, filled=True, feature_names=iris.feature_names, class_names=iris.target_names, rounded=True)
plt.show()
# Out:
# Accuracy: 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00         9
#            2       1.00      1.00      1.00        11
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %%
import seaborn as sns
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier,plot_tree
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

titanic = sns.load_dataset('titanic')


titanic = titanic.dropna(subset=["survived" , "sex", "age", "embarked"])

label_encoder = LabelEncoder()
titanic['sex'] = label_encoder.fit_transform(titanic['sex'])
titanic['embarked'] = label_encoder.fit_transform(titanic['embarked'])

x = titanic[['pclass', 'sex', 'fare', 'age', 'embarked']]
y = titanic['survived']

X_train, X_test, Y_train, Y_test = train_test_split(x,y,test_size=0.2,random_state=42)

clf = DecisionTreeClassifier(random_state=42)
clf.fit(X_train, Y_train)

plt.figure(figsize=(15,10))
plot_tree(clf, feature_names=x.columns, class_names=['Not Survived', 'Survived'], filled=True, rounded=True)
plt.show()

y_predict = clf.predict(X_test)

print(classification_report(Y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.78      0.72        80
#            1       0.65      0.52      0.58        63
#
#     accuracy                           0.66       143
#    macro avg       0.66      0.65      0.65       143
# weighted avg       0.66      0.66      0.66       143

# %%
import seaborn as sns
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier,plot_tree
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

titanic = sns.load_dataset('titanic')


titanic = titanic.dropna(subset=["survived" , "sex", "age", "embarked"])

label_encoder = LabelEncoder()
titanic['sex'] = label_encoder.fit_transform(titanic['sex'])
titanic['embarked'] = label_encoder.fit_transform(titanic['embarked'])

x = titanic[['pclass', 'sex', 'fare', 'age', 'embarked']]
y = titanic['survived']

X_train, X_test, Y_train, Y_test = train_test_split(x,y,test_size=0.2,random_state=42)

clf = DecisionTreeClassifier(max_depth=5,min_samples_leaf=5,min_samples_split=5,random_state=42)
clf.fit(X_train, Y_train)

plt.figure(figsize=(15,10))
plot_tree(clf, feature_names=x.columns, class_names=['Not Survived', 'Survived'], filled=True, rounded=True)
plt.show()

y_predict = clf.predict(X_test)

print("AFTER HYPER TUNNING:")
print(classification_report(Y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.94      0.82        80
#            1       0.88      0.56      0.68        63
#
#     accuracy                           0.77       143
#    macro avg       0.80      0.75      0.75       143
# weighted avg       0.79      0.77      0.76       143

# %%
import seaborn as sns
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier,plot_tree
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

titanic = sns.load_dataset('titanic')


titanic = titanic.dropna(subset=["survived" , "sex", "age", "embarked"])

label_encoder = LabelEncoder()
titanic['sex'] = label_encoder.fit_transform(titanic['sex'])
titanic['embarked'] = label_encoder.fit_transform(titanic['embarked'])

x = titanic[['pclass', 'sex', 'fare', 'age', 'embarked']]
y = titanic['survived']

X_train, X_test, Y_train, Y_test = train_test_split(x,y,test_size=0.2,random_state=42)

clf = DecisionTreeClassifier(max_depth=5,min_samples_leaf=5,min_samples_split=10,random_state=42)
clf.fit(X_train, Y_train)

plt.figure(figsize=(15,10))
plot_tree(clf, feature_names=x.columns, class_names=['Not Survived', 'Survived'], filled=True, rounded=True)
plt.show()

y_predict = clf.predict(X_test)
print("AFTER PRUNNING:")
print(classification_report(Y_test, y_predict))
# Out:
# AFTER PRUNNING:
#               precision    recall  f1-score   support
#
#            0       0.73      0.94      0.82        80
#            1       0.88      0.56      0.68        63
#
#     accuracy                           0.77       143
#    macro avg       0.80      0.75      0.75       143
# weighted avg       0.79      0.77      0.76       143

# %%
import seaborn as sns
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier,plot_tree
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, cross_val_score
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

titanic = sns.load_dataset('titanic')


titanic = titanic.dropna(subset=["survived" , "sex", "age", "embarked"])

label_encoder = LabelEncoder()
titanic['sex'] = label_encoder.fit_transform(titanic['sex'])
titanic['embarked'] = label_encoder.fit_transform(titanic['embarked'])

x = titanic[['pclass', 'sex', 'fare', 'age', 'embarked']]
y = titanic['survived']

X_train, X_test, Y_train, Y_test = train_test_split(x,y,test_size=0.2,random_state=42)

clf = DecisionTreeClassifier(max_depth=5,min_samples_leaf=5,min_samples_split=10,random_state=42)
cv_score = cross_val_score(clf,x,y,cv=5,scoring='accuracy')


clf.fit(X_train, Y_train)


plt.figure(figsize=(15,10))
plot_tree(clf, feature_names=x.columns, class_names=['Not Survived', 'Survived'], filled=True, rounded=True)
plt.show()

y_predict = clf.predict(X_test)

print("Cross Validation score (K=5): ",cv_score)
print("Mean Cross Validation score: ",np.mean(cv_score))
print("REPORT:")
print(classification_report(Y_test, y_predict))
# Out:
# Cross Validation score (K=5):  [0.72027972 0.8041958  0.82394366 0.78873239 0.82394366]
# Mean Cross Validation score:  0.7922190485570767
# REPORT:
#               precision    recall  f1-score   support
#
#            0       0.73      0.94      0.82        80
#            1       0.88      0.56      0.68        63
#
#     accuracy                           0.77       143
#    macro avg       0.80      0.75      0.75       143
# weighted avg       0.79      0.77      0.76       143
